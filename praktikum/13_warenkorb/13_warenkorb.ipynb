# %% [markdown]
# # Computational Thinking WS2023/24
# **Autoren:**
# + Prof. Benedikt Dietrich
# + Prof. Martin Hobelsberger

# %% [markdown]
# # Online-Shop
#
# In der folgenden Aufgabe soll der Warenkorb eines Online-Shops realisiert werden. Das folgende Klassendiagramm zeigt die einzelnen Klassen, deren Attribute (Member-Variablen) und Methoden (Member-Funktionen):
#
# ![warenkorb.png](attachment:warenkorb.png)
#
# Sie werden in dieser Aufgabe Klasse für Klasse entwickeln.
# Die notwendigen Beschreibungen der einzelnen Klassen finden Sie in den jeweiligen Teilaufgaben.

# %% [markdown]
# ## 1. Klasse `Product`
#
# Die Klasse `Product` stellt ein bestimmtes Produkt dar.
#
# Attribute (Member-Variablen):
#
# * `PRODUCT_ID`: eine eineindeutige Nummer
# * `NAME`: Der Name des Produkts
# * `price`: Der Preis des Produkts
#
# Methoden (Member-Funktionen):
#
# * `__init__()`: Konstruktor. Beim Erzeugen eines neuen Produkts soll ein Name und ein Preis übergeben werden müssen.
# * `get_product_id()`: Liefert die Produkt-ID zurück.
# * `get_name()`: Liefert den Namen des Produkts zurück.
# * `get_price()`: Liefert den Preis des Produkts zurück.
# * `set_price()`: Setzt den Preis des Produkts auf den Preis, der der Funktion übergeben wird.
# * `__str__()`: Liefert einen `String` zurück, der das Produkt beschreibt.
#
# Der Code
#
# ```Python
#     apple = Product("Apfel", 0.39)
#     banana = Product("Banane", 0.45)
#     print(apple)
#     print(banana)
# ```
#
# soll folgendes ausgeben:
#
# ```txt
#     Apfel (ID = 0): 0.39 €
#     Banane (ID = 1): 0.45 €
# ```
#
# Setzen Sie die Klasse entsprechend um.
# Beachten Sie die vorgegebenen Sichtbarkeiten der Member-Methoden und Variablen. (`+` steht für `public`, `-` steht für `private`).
#
# *Hinweis: Spicken Sie für die Umsetzung der Produkt-ID bei der Klasse `Agents`. Vollziehen Sie nach wie `nAgents` verwendet wurde, um jedem Agenten einen Code zuzuweisen und setzen Sie analog die Produkt-ID um.*

# %%
class Product:
...

# %%
# Der folgende Code zeigt, wie die Klasse genutzt werden können soll

apple = Product("Apfel", 0.39)
banana = Product("Banane", 0.45)
print(apple)
print(banana)

# %% [markdown]
# ## 2. Die Klasse `Shop`
#
# Die Klasse `Shop` stellt den Shop mit seinen Produkten dar.
#
# Attribute (Member-Variablen):
#
# * `products`: eine Liste mit Produkten, die man im Shop kaufen kann.
#
# Methoden (Member-Funktionen):
#
# * `__init__()`: Konstruktor. Beim Erzeugen soll eine leere Liste `products` angelegt werden.
# * `add_product()`: Fügt ein Produkt zum Inventar des Shops hinzu (zur Liste `products`).
# * `go_shopping()`: Wird in einer späteren Aufgabe umgesetzt. Legen Sie die Methode schon mal an ohne sie konkret zu implementieren.
# * `__str__()`: Liefert einen `String` zurück, der alle im Shop erhältlichen Produkte ausgibt.
#
# Der Code
#
# ```Python
#     shop = Shop()
#     shop.add_product(Product("Apfel", 0.39))
#     shop.add_product(Product("Banane", 0.45))
#     shop.add_product(Product("Birne", 0.35))
#     print(shop)
# ```
#
# soll folgendes ausgeben:
#
# ```txt
#     1) Apfel (ID = 2): 0.39 €
#     2) Banane (ID = 3): 0.45 €
#     3) Birne (ID = 4): 0.35 €
# ```
#
# Setzen Sie die Klasse entsprechend um.
# Beachten Sie die vorgegebenen Sichtbarkeiten der Member-Methoden und Variablen im Klassendiagramm. (`+` steht für `public`, `-` steht für `private`).

# %%
class Shop:
...

# %%
# Der folgende Code zeigt, wie die Klasse genutzt werden können soll

shop = Shop()
shop.add_product(Product("Apfel", 0.39))
shop.add_product(Product("Banane", 0.45))
shop.add_product(Product("Birne", 0.35))
print(shop)

# %% [markdown]
# ## 3. Klasse `ShoppingCartItem`
#
# Die Klasse `ShoppingCartItem` stellt einen Eintrag im Warenkorb dar.
# Der Eintrag beinhaltet das Produkt sowie die von dem Produkt gewünschte Anzahl.
#
# Attribute (Member-Variablen):
#
# * `product`: das zu diesem Warenkorb-Eintrag gehörende Produkt.
# * `quantity`: die zu bestellende Anzahl von diesem Produkt.
#
# Methoden (Member-Funktionen):
#
# * `__init__()`: Konstruktor. Beim Erzeugen soll das Produkt übergeben werden müssen. Der Parameter `quantity` soll optional sein. Wird der Parameter bei der Konstruktion nicht übergeben, soll die Anzahl per Default auf `1` gesetzt werden.
# * `get_quantity()`: Liefert die Anzahl zurück.
# * `set_quantity()`: Setzt die Anzahl auf den übergebenen Wert.
# * `get_subtotal()`: Liefert den Gesamtpreis zurück, d.h. Anzahl mal Produktpreis.
# * `is_product()`: Liefert `True` zurück, falls es sich beim übergebenen Produkt um das Produkt handelt, welches mit diesem Warenkorbeintrag bestellt werden soll. Ansonsten liefert die Funktion `False` zurück.
# * `__str__()`: Liefert einen `String` zurück, der den Warenkorbeintrag beschreibt.
#
# Der Code
#
# ```Python
#     apples = ShoppingCartItem(apple)
#     apples.set_quantity(3)
#     bananas = ShoppingCartItem(banana)
#     bananas.set_quantity(bananas.get_quantity() + 5)
#
#     print(apples)
#     print(bananas)
# ```
#
# soll folgendes ausgeben:
#
# ```txt
#     3 x Apfel      1.17 €
#     6 x Banane     2.70 €
# ```
#
# Achten Sie hierfür in der Funktion `__str__` auf eine korrekte Formatierung.
#
# Setzen Sie die Klasse entsprechend um.
# Beachten Sie die vorgegebenen Sichtbarkeiten der Member-Methoden und Variablen im Klassendiagramm. (`+` steht für `public`, `-` steht für `private`).

# %%
# Hilfe zur Formatierung

# Folgender Code zeigt, wie sie 
# - einen String mit definierter Breite ausgeben (und die fehlenden Zeichen rechts mit Leerzeichen aufgefüllt werden)
# - eine Gleitkommazahl mit definierter Anzahl an Nachkommastellen ausgeben
# - eine Integer-Zahl mit definierter Breite ausgeben (und die Dezimalstellen links mit Leerzeichen aufgefüllt werden)
name = "123"
print(f"{name:10s}Nach insgesamt 10 Zeichen kommt dieser Satz.")

value = 1.23456789
print(f"{value:.4f}")

value2 = 99
print(f"{value2:10d}: Die Zahl wird mit 10 Zeichen dargestellt. Die fehlenden Ziffern werden mit Leerzeichen von links aufgefüllt.")

# %%
class ShoppingCartItem:
...

# %%
# Der folgende Code zeigt, wie die Klasse genutzt werden können soll

apples = ShoppingCartItem(apple)                 # Eintrag für einen Apfel
apples.set_quantity(3)                           # Auf drei Bananen ändern
bananas = ShoppingCartItem(banana)               # Eine Banane hinzufügen
bananas.set_quantity(bananas.get_quantity() + 5) # Nochmal 5 Bananen hinzufügen

print(apples)
print(bananas)

# %% [markdown]
# ## 4. Klasse `ShoppingCart`
#
# Die Klasse `ShoppingCart` stellt den Warenkorb dar, der aus 0 bis n Warenkorbeinträgen besteht (`ShoppingCartItem`).
#
# Attribute (Member-Variablen):
#
# * `items`: Liste an Warenkorbeinträgen (Objekte vom Typ `ShoppingCartItem`)
#
# Methoden (Member-Funktionen):
#
# * `__init__()`: Konstruktor. Beim Erzeugen wird eine leere Liste `items` angelegt.
# * `__get_shopping_cart_item()`: Durchsucht die Warenkorbeinträge nach dem übergebenen Produkt. Wird das Produkt gefunden, liefert die Funktion den Warenkorbeintrag zurück. Ist das Produkt noch nicht Teil des Warenkorbs, soll die Funktion `None` zurückliefern. Verwenden Sie zur Realisierung dieser Methode die Methode `is_product` der Klasse `Product`.
# * `add()`: Prüft, ob das übergebene Produkt bereits im Warenkorb vorhanden ist. Ist dies der Fall, erhöht es die Anzahl des Warenkorbeintrags. Ist das Produkt noch nicht Teil des Warenkorbs, erzeugt die Methode einen neuen Warenkorbeintrag `ShoppingCartItem` und fügt diesen zu `items` hinzu. Verwenden Sie für die Umsetzung die Methoden `__get_shopping_cart_item()`, sowie `set_quantity()` und `get_quantity()` der Klasse `ShoppingCartItem`.
# * `get_total()`: Berechnet den Gesamtpreis des Warenkorbs und liefert diesen zurück.
# * `__str__()`: Liefert einen `String` zurück, der den Warenkorbinhalt zeigt und den aktuellen Gesamtpreis ausgibt.
#
# Der Code
#
# ```Python
#     shopping_cart = ShoppingCart()
#     shopping_cart.add(apple)   # Einen Apfel zum Warenkorb hinzufügen
#     shopping_cart.add(apple)   # Noch ein Apfel
#     shopping_cart.add(apple)   # Noch ein Apfel
#     shopping_cart.add(banana)  # Eine Banane
#     shopping_cart.add(banana)  # Noch eine Banane
#     print(shopping_cart)
# ```
#
# soll folgendes ausgeben:
#
# ```txt
#  3 x Apfel      1.17 €
#  2 x Banane     0.90 €
# ======================
# Total           2.07 €
# ```
#
# Achten Sie hierfür in der Funktion `__str__` auf eine korrekte Formatierung.
#
# Setzen Sie die Klasse entsprechend um.
# Beachten Sie die vorgegebenen Sichtbarkeiten der Member-Methoden und Variablen im Klassendiagramm. (`+` steht für `public`, `-` steht für `private`).

# %%
class ShoppingCart:
...

# %%
# Der folgende Code zeigt, wie die Klasse genutzt werden können soll

shopping_cart = ShoppingCart()
shopping_cart.add(apple)   # Einen Apfel zum Warenkorb hinzufügen
shopping_cart.add(apple)   # Noch ein Apfel
shopping_cart.add(apple)   # Noch ein Apfel
shopping_cart.add(banana)  # Eine Banane
shopping_cart.add(banana)  # Noch eine Banane
print(shopping_cart)

shopping_cart.remove(banana) # Remove all bananas from the shopping cart
print(shopping_cart)

# %% [markdown]
# ## 5. Erweiterung der Klasse `Shop`
#
# Nun soll die Klasse `Shop` noch um eine Menüführung erweitert werden, sodass wir im Shop auch wirklich einkaufen können.
#
# Schreiben Sie eine Funktion `go_shopping()`, welche die aktuellen Produkte des Shops zur Auswahl stellt.
# Fragen Sie den Nutzer welches der Produkte er kaufen will und fügen Sie das gewählte Produkt zum Warenkorb hinzu.
# Dies soll solange passieren, bis der Nutzer `x` eintippt.
# Die Funktion soll ein Objekt vom Typ `ShoppingCart` zurückliefern.
#
# Eine Beispielausgabe könnte wie folgt aussehen:
#
# ```txt
#
# In unserem Shop gibt es folgende Produkte:
# 1) Apfel (ID = 5): 0.39 €
# 2) Banane (ID = 6): 0.45 €
# 3) Birne (ID = 7): 0.35 €
#
# Sie haben 1) gewählt.
#
# Aktueller Inhalt des Warenkorbs:
#  1 x Apfel      0.39 €
# ======================
# Total           0.39 €
#
# Sie haben 1) gewählt.
#
# Aktueller Inhalt des Warenkorbs:
#  2 x Apfel      0.78 €
# ======================
# Total           0.78 €
#
# Sie haben 2) gewählt.
#
# Aktueller Inhalt des Warenkorbs:
#  2 x Apfel      0.78 €
#  1 x Banane     0.45 €
# ======================
# Total           1.23 €
#
# Sie haben 1) gewählt.
#
# Aktueller Inhalt des Warenkorbs:
#  3 x Apfel      1.17 €
#  1 x Banane     0.45 €
# ======================
# Total           1.62 €
#
# Ihr Warenkorb wurde zusammengestellt.
# ```

# %%
class Shop:
...

# %%
# Der folgende Code zeigt, wie die Klasse genutzt werden können soll

shop = Shop()                              # Shop erstellen
shop.add_product(Product("Apfel", 0.39))   # Produkte hinzufügen
shop.add_product(Product("Banane", 0.45))
shop.add_product(Product("Birne", 0.35))
shopping_cart = shop.go_shopping()         # Shoppen
print(shopping_cart)                       # Warenkorb ausgeben
